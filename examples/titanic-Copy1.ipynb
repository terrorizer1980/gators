# %% [markdown]
# # binary classification example - titanic dataset

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import copy
import numpy as np
import pandas as pd
from pandas.testing import assert_frame_equal
from pandas.testing import assert_series_equal
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
import treelite
import treelite_runtime
import dill
from sklearn.metrics import make_scorer
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import RandomizedSearchCV
from xgboost import XGBClassifier
import seaborn as sns
cm = sns.color_palette("viridis", as_cmap=True)
cm = sns.color_palette("vlag", as_cmap=True)

# %% [markdown]
# **Gators** imports

# %%
from gators.util import util
# data cleaning
from gators.data_cleaning import (
    ConvertColumnDatatype,
    DropHighNaNRatio,
    DropLowCardinality,
    DropHighCardinality,
    DropDatatypeColumns,
    DropColumns,
    KeepColumns,
    Replace,
)
# imputers
from gators.imputers import (
    NumericsImputer, 
    ObjectImputer,
)
# encoders
from gators.encoders import (
    OrdinalEncoder, 
    WOEEncoder,
    TargetEncoder,
    OneHotEncoder,
    
)
# binning
from gators.binning import (
    BinRareCategories,
    BinSingleTargetClassCategories,
    Binning,
    CustomBinning,
    QuantileBinning,
    TreeBinning,
)
# feature generation
from gators.feature_generation import (
    PolynomialFeatures,
    ElementaryArithmetics,
    PolynomialObjectFeatures,
    IsNull,
)
from gators.feature_generation_str import (
    StringContains,
    StringLength,
    Extract,
    SplitExtract,
)
# feature selection
from gators.feature_selection import (
    SelectFromModel,
    InformationValue
)
# model building
from gators.model_building import (
    TrainTestSplit,
    XGBBoosterBuilder,
    XGBTreeliteDumper,
)
# pipeline
from gators.pipeline import Pipeline

# %% [markdown]
# ## offline pipeline - feature selection

# %% [markdown]
# **Pipeline composed of the following transformations**
# * String features
# * Imputers
# * Binning
# * Polynomial Features
# * Encoder

# %% [markdown]
# ### with pandas

# %%
data = pd.read_parquet('data/titanic.parquet')
data = data.reset_index(drop=True)
y = data['Survived']
X = data.drop('Survived', axis=1)
train_test_split = TrainTestSplit(test_ratio=0.3, strategy='ordered')
X_train, X_test, y_train, y_test = train_test_split.transform(X, y)

# %%
X_train.head(2)
# Out:
#    Pclass                                               Name     Sex   Age  \
# 0       3                            Braund, Mr. Owen Harris    male  22.0
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
#
#    SibSp  Parch     Ticket     Fare Cabin Embarked
# 0      1      0  A/5 21171   7.2500  None        S
# 1      1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# ### data analysis

# %%
label_counts = data['Survived'].value_counts(normalize=True).sort_values().iloc[::-1]
label_counts.plot(
    kind='barh', 
    figsize=(4, 3), 
    title='Label Distribution',
);

# %% [markdown]
# #### Numerical columns

# %%
steps = [
    
    ('NumericsImputer', NumericsImputer(strategy='mean')),
    ('ElementaryArithmetics', ElementaryArithmetics(
        operator='+',
        columns_a=['SibSp'], 
        columns_b=['Parch'], 
        column_names=['FamilySize'])),
    ('TreeBinning', TreeBinning(
        tree=DecisionTreeClassifier(max_depth=3, min_samples_leaf=120),
        inplace=True)),
    ('Encoder', WOEEncoder()),
]
pipe = Pipeline(steps=steps)
_ = pipe.fit(X_train[['Pclass', 'Age', 'SibSp', 'Parch', 'Fare']], y_train)

# %%
mapping = pd.DataFrame(pipe.steps[-1][1].mapping)
vmin = mapping.min().min()
vmax = mapping.max().max()
mapping.style.background_gradient(cmap=cm, vmin=vmin, vmax=vmax)
# Out:
# <style type="text/css">
# #T_71281_row0_col0 {
#   background-color: #b65453;
#   color: #f1f1f1;
# }
# #T_71281_row0_col1 {
#   background-color: #f3e2e0;
#   color: #000000;
# }
# #T_71281_row0_col2 {
#   background-color: #d2d7e1;
#   color: #000000;
# }
# #T_71281_row0_col3 {
#   background-color: #d4d8e2;
#   color: #000000;
# }
# #T_71281_row0_col4 {
#   background-color: #2369bd;
#   color: #f1f1f1;
# }
# #T_71281_row0_col5 {
#   background-color: #abb9d0;
#   color: #000000;
# }
# #T_71281_row1_col0 {
#   background-color: #d59c99;
#   color: #f1f1f1;
# }
# #T_71281_row1_col1 {
#   background-color: #b3bfd3;
#   color: #000000;
# }
# #T_71281_row1_col2, #T_71281_row1_col4 {
#   background-color: #e4c0be;
#   color: #000000;
# }
# #T_71281_row1_col3 {
#   background-color: #d7a09d;
#   color: #000000;
# }
# #T_71281_row1_col5 {
#   background-color: #d49a97;
#   color: #f1f1f1;
# }
# #T_71281_row2_col0 {
#   background-color: #698cbe;
#   color: #f1f1f1;
# }
# #T_71281_row2_col1 {
#   background-color: #f7eae8;
#   color: #000000;
# }
# #T_71281_row2_col2, #T_71281_row2_col3, #T_71281_row3_col0, #T_71281_row3_col1, #T_71281_row3_col2, #T_71281_row3_col3, #T_71281_row3_col5 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_71281_row2_col4 {
#   background-color: #faf0ef;
#   color: #000000;
# }
# #T_71281_row2_col5 {
#   background-color: #deb1ae;
#   color: #000000;
# }
# #T_71281_row3_col4 {
#   background-color: #a9373b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_71281_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Pclass</th>
#       <th class="col_heading level0 col1" >Age</th>
#       <th class="col_heading level0 col2" >SibSp</th>
#       <th class="col_heading level0 col3" >Parch</th>
#       <th class="col_heading level0 col4" >Fare</th>
#       <th class="col_heading level0 col5" >FamilySize</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71281_level0_row0" class="row_heading level0 row0" >_0</th>
#       <td id="T_71281_row0_col0" class="data row0 col0" >0.402706</td>
#       <td id="T_71281_row0_col1" class="data row0 col1" >-0.263653</td>
#       <td id="T_71281_row0_col2" class="data row0 col2" >-0.592266</td>
#       <td id="T_71281_row0_col3" class="data row0 col3" >-0.583214</td>
#       <td id="T_71281_row0_col4" class="data row0 col4" >-1.290241</td>
#       <td id="T_71281_row0_col5" class="data row0 col5" >-0.761568</td>
#     </tr>
#     <tr>
#       <th id="T_71281_level0_row1" class="row_heading level0 row1" >_1</th>
#       <td id="T_71281_row1_col0" class="data row1 col0" >0.061088</td>
#       <td id="T_71281_row1_col1" class="data row1 col1" >-0.725008</td>
#       <td id="T_71281_row1_col2" class="data row1 col2" >-0.114959</td>
#       <td id="T_71281_row1_col3" class="data row1 col3" >0.040005</td>
#       <td id="T_71281_row1_col4" class="data row1 col4" >-0.113023</td>
#       <td id="T_71281_row1_col5" class="data row1 col5" >0.066140</td>
#     </tr>
#     <tr>
#       <th id="T_71281_level0_row2" class="row_heading level0 row2" >_2</th>
#       <td id="T_71281_row2_col0" class="data row2 col0" >-1.048984</td>
#       <td id="T_71281_row2_col1" class="data row2 col1" >-0.300314</td>
#       <td id="T_71281_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_71281_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_71281_row2_col4" class="data row2 col4" >-0.329479</td>
#       <td id="T_71281_row2_col5" class="data row2 col5" >-0.042864</td>
#     </tr>
#     <tr>
#       <th id="T_71281_level0_row3" class="row_heading level0 row3" >_3</th>
#       <td id="T_71281_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_71281_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_71281_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_71281_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_71281_row3_col4" class="data row3 col4" >0.532566</td>
#       <td id="T_71281_row3_col5" class="data row3 col5" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
mapping = pd.DataFrame(pipe.steps[-1][1].mapping)
vmin = mapping.min().min()
vmax = mapping.max().max()
vmin = - vmax
for c in pipe.steps[-2][1].mapping.keys():
    splits = pipe.steps[-2][1].mapping[c]
    woe = mapping[[c]]
    woe.columns = [woe.columns[0]+' WOE']
    woe['bins'] = woe.index
    woe['bins'] = woe['bins'].replace(splits)
    woe = woe.set_index('bins').dropna()
    woe.style.background_gradient(cmap=cm, vmin=vmin, vmax=vmax)
# Out:
# <style type="text/css">
# #T_13ab6_row0_col0 {
#   background-color: #bf6765;
#   color: #f1f1f1;
# }
# #T_13ab6_row1_col0 {
#   background-color: #f5e5e4;
#   color: #000000;
# }
# #T_13ab6_row2_col0 {
#   background-color: #2369bd;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_13ab6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Pclass WOE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >bins</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13ab6_level0_row0" class="row_heading level0 row0" >(-inf, 1.5]</th>
#       <td id="T_13ab6_row0_col0" class="data row0 col0" >0.402706</td>
#     </tr>
#     <tr>
#       <th id="T_13ab6_level0_row1" class="row_heading level0 row1" >(1.5, 2.5]</th>
#       <td id="T_13ab6_row1_col0" class="data row1 col0" >0.061088</td>
#     </tr>
#     <tr>
#       <th id="T_13ab6_level0_row2" class="row_heading level0 row2" >(2.5, inf)</th>
#       <td id="T_13ab6_row2_col0" class="data row2 col0" >-1.048984</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d5dee_row0_col0 {
#   background-color: #9baecb;
#   color: #000000;
# }
# #T_d5dee_row1_col0 {
#   background-color: #2369bd;
#   color: #f1f1f1;
# }
# #T_d5dee_row2_col0 {
#   background-color: #8da4c6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d5dee_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Age WOE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >bins</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5dee_level0_row0" class="row_heading level0 row0" >(-inf, 25.5]</th>
#       <td id="T_d5dee_row0_col0" class="data row0 col0" >-0.263653</td>
#     </tr>
#     <tr>
#       <th id="T_d5dee_level0_row1" class="row_heading level0 row1" >(25.5, 30.5]</th>
#       <td id="T_d5dee_row1_col0" class="data row1 col0" >-0.725008</td>
#     </tr>
#     <tr>
#       <th id="T_d5dee_level0_row2" class="row_heading level0 row2" >(30.5, inf)</th>
#       <td id="T_d5dee_row2_col0" class="data row2 col0" >-0.300314</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_6aa86_row0_col0 {
#   background-color: #2369bd;
#   color: #f1f1f1;
# }
# #T_6aa86_row1_col0 {
#   background-color: #d5d9e3;
#   color: #000000;
# }
# </style>
# <table id="T_6aa86_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >SibSp WOE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >bins</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6aa86_level0_row0" class="row_heading level0 row0" >(-inf, 0.5]</th>
#       <td id="T_6aa86_row0_col0" class="data row0 col0" >-0.592266</td>
#     </tr>
#     <tr>
#       <th id="T_6aa86_level0_row1" class="row_heading level0 row1" >(0.5, inf)</th>
#       <td id="T_6aa86_row1_col0" class="data row1 col0" >-0.114959</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_ef647_row0_col0 {
#   background-color: #2369bd;
#   color: #f1f1f1;
# }
# #T_ef647_row1_col0 {
#   background-color: #f8edeb;
#   color: #000000;
# }
# </style>
# <table id="T_ef647_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Parch WOE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >bins</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef647_level0_row0" class="row_heading level0 row0" >(-inf, 0.5]</th>
#       <td id="T_ef647_row0_col0" class="data row0 col0" >-0.583214</td>
#     </tr>
#     <tr>
#       <th id="T_ef647_level0_row1" class="row_heading level0 row1" >(0.5, inf)</th>
#       <td id="T_ef647_row1_col0" class="data row1 col0" >0.040005</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_3a674_row0_col0 {
#   background-color: #2369bd;
#   color: #f1f1f1;
# }
# #T_3a674_row1_col0 {
#   background-color: #d5d9e3;
#   color: #000000;
# }
# #T_3a674_row2_col0 {
#   background-color: #829cc3;
#   color: #f1f1f1;
# }
# #T_3a674_row3_col0 {
#   background-color: #a9373b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3a674_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Fare WOE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >bins</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a674_level0_row0" class="row_heading level0 row0" >(-inf, 10.48125]</th>
#       <td id="T_3a674_row0_col0" class="data row0 col0" >-1.290241</td>
#     </tr>
#     <tr>
#       <th id="T_3a674_level0_row1" class="row_heading level0 row1" >(10.48125, 19.73335]</th>
#       <td id="T_3a674_row1_col0" class="data row1 col0" >-0.113023</td>
#     </tr>
#     <tr>
#       <th id="T_3a674_level0_row2" class="row_heading level0 row2" >(19.73335, 40.8521]</th>
#       <td id="T_3a674_row2_col0" class="data row2 col0" >-0.329479</td>
#     </tr>
#     <tr>
#       <th id="T_3a674_level0_row3" class="row_heading level0 row3" >(40.8521, inf)</th>
#       <td id="T_3a674_row3_col0" class="data row3 col0" >0.532566</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d087c_row0_col0 {
#   background-color: #2369bd;
#   color: #f1f1f1;
# }
# #T_d087c_row1_col0 {
#   background-color: #f4e3e2;
#   color: #000000;
# }
# #T_d087c_row2_col0 {
#   background-color: #f1eff2;
#   color: #000000;
# }
# </style>
# <table id="T_d087c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >FamilySize WOE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >bins</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d087c_level0_row0" class="row_heading level0 row0" >(-inf, 0.5]</th>
#       <td id="T_d087c_row0_col0" class="data row0 col0" >-0.761568</td>
#     </tr>
#     <tr>
#       <th id="T_d087c_level0_row1" class="row_heading level0 row1" >(0.5, 1.5]</th>
#       <td id="T_d087c_row1_col0" class="data row1 col0" >0.066140</td>
#     </tr>
#     <tr>
#       <th id="T_d087c_level0_row2" class="row_heading level0 row2" >(1.5, inf)</th>
#       <td id="T_d087c_row2_col0" class="data row2 col0" >-0.042864</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Categorical columns

# %%
steps = [
    ('SplitExtractName', SplitExtract(['Name'], [', '], [1], ['Dummy'])),
    ('SplitExtractTitle', SplitExtract(['Dummy'], ['.'], [0], ['Title'])),
    ('DropColumns', DropColumns(['Ticket', 'Name',  'Dummy'])),
    ('ObjectImputer', ObjectImputer(strategy='constant', value='MISSING')),
    ('BinSingleTargetClassCategories', BinSingleTargetClassCategories()),
    ('Encoder', WOEEncoder()),
]
pipe = Pipeline(steps=steps)
_ = pipe.fit(X_train[['Name', 'Sex', 'Ticket','Embarked']].copy(), y_train)

# %%
pd.DataFrame(pipe.steps[-1][1].mapping).fillna('X')
# Out:
#                           Sex  Embarked     Title
# female               1.087151         X         X
# male                -1.472597         X         X
# C|MISSING                   X  0.130265         X
# Q                           X -0.140582         X
# S                           X -0.628394         X
# Don|Dr|Rev|Mr               X         X -1.673433
# Major                       X         X       0.0
# Master                      X         X  0.071459
# Miss                        X         X  0.898856
# Mrs|Lady|Mme|Ms|Sir         X         X  1.406362

# %%
steps = [
    ('StringLength', StringLength(columns=['Ticket'])),
    ('SplitExtractName', SplitExtract(['Name'], [', '], [1], ['Dummy'])),
    ('SplitExtractTitle', SplitExtract(['Dummy'], ['.'], [0], ['Title'])),
    ('IsNull', IsNull(columns=['Age', 'Cabin'])),
    ('DropColumns', DropColumns(['Name',  'Dummy', 'Cabin', 'Ticket'])),
    ('ObjectImputer', ObjectImputer(strategy='constant', value='MISSING')),
    ('BinSingleTargetClassCategories', BinSingleTargetClassCategories()),
    ('NumericsImputer', NumericsImputer(strategy='mean')),
    ('ElementaryArithmetics', ElementaryArithmetics(
        operator='+',
        columns_a=['SibSp'], 
        columns_b=['Parch'], 
        column_names=['FamilySize'])),
    ('TreeBinning', TreeBinning(
        tree=DecisionTreeClassifier(max_depth=3, min_samples_leaf=120),
        inplace=True)),
    ('Encoder', WOEEncoder()),
]
pipe = Pipeline(steps=steps)
_ = pipe.fit(X_train.copy(), y_train)

# %%
pipe.transform(X_train.copy()).isnull().sum()
# Out:
# Pclass            0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Fare              0
# Embarked          0
# Ticket__length    0
# Title             0
# Age__is_null      0
# Cabin__is_null    0
# FamilySize        0
# dtype: int64

# %%
from IPython.display import display
cmap = sns.color_palette("viridis", as_cmap=True)
# cmap = sns.color_palette("vlag", as_cmap=True)

def display_encoder_mapping_nb(self, cmap=cmap):
    encoder_list = [p[1] for p in self.steps if 'Encoder' in str(p[1])]
    if not encoder_list:
        return
    encoder = encoder_list[0]
    describe = str(encoder).replace('Encoder', '')[:-2].lower()
    binning_list = [p[1] for p in self.steps if 'Binning' in str(p[1])]
    if binning_list:
        binning_mapping = binning_list[0].mapping
    else:
        binning_mapping = {}
    mapping = pd.DataFrame(encoder.mapping)
    vmin = mapping.min().min()
    vmax = mapping.max().max()
    columns = list((mapping.max()-mapping.min()).sort_values(ascending=False).index)
    for c in columns:
        values = mapping[[c]]
        values['bins'] = values.index
        if c in binning_mapping:
            splits = binning_mapping[c]
            values['bins'] = values['bins'].replace(splits)
        else:
            values = values.sort_values(c)
        values = values.set_index('bins').dropna()
        values.index.name = f'{c}'
        values.columns = [f'{describe} values']
        display(values.style.background_gradient(cmap=cmap, vmin=vmin, vmax=vmax))

display_encoder_mapping_nb(pipe)
# Out:
# ['Title', 'Sex', 'Fare', 'Pclass', 'Cabin__is_null', 'FamilySize', 'Embarked', 'Ticket__length', 'Parch', 'SibSp', 'Age', 'Age__is_null']
# <style type="text/css">
# #T_f0296_row0_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_f0296_row1_col0 {
#   background-color: #1e9b8a;
#   color: #f1f1f1;
# }
# #T_f0296_row2_col0 {
#   background-color: #1fa188;
#   color: #f1f1f1;
# }
# #T_f0296_row3_col0 {
#   background-color: #90d743;
#   color: #000000;
# }
# #T_f0296_row4_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# </style>
# <table id="T_f0296_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >woe values</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Title</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0296_level0_row0" class="row_heading level0 row0" >Don|Dr|Rev|Mr</th>
#       <td id="T_f0296_row0_col0" class="data row0 col0" >-1.673433</td>
#     </tr>
#     <tr>
#       <th id="T_f0296_level0_row1" class="row_heading level0 row1" >Major</th>
#       <td id="T_f0296_row1_col0" class="data row1 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f0296_level0_row2" class="row_heading level0 row2" >Master</th>
#       <td id="T_f0296_row2_col0" class="data row2 col0" >0.071459</td>
#     </tr>
#     <tr>
#       <th id="T_f0296_level0_row3" class="row_heading level0 row3" >Miss</th>
#       <td id="T_f0296_row3_col0" class="data row3 col0" >0.898856</td>
#     </tr>
#     <tr>
#       <th id="T_f0296_level0_row4" class="row_heading level0 row4" >Mrs|Lady|Mme|Ms|Sir</th>
#       <td id="T_f0296_row4_col0" class="data row4 col0" >1.406362</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_2bc18_row0_col0 {
#   background-color: #48186a;
#   color: #f1f1f1;
# }
# #T_2bc18_row1_col0 {
#   background-color: #bade28;
#   color: #000000;
# }
# </style>
# <table id="T_2bc18_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >woe values</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2bc18_level0_row0" class="row_heading level0 row0" >male</th>
#       <td id="T_2bc18_row0_col0" class="data row0 col0" >-1.472597</td>
#     </tr>
#     <tr>
#       <th id="T_2bc18_level0_row1" class="row_heading level0 row1" >female</th>
#       <td id="T_2bc18_row1_col0" class="data row1 col0" >1.087151</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a6697_row0_col0 {
#   background-color: #472c7a;
#   color: #f1f1f1;
# }
# #T_a6697_row1_col0 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_a6697_row2_col0 {
#   background-color: #26818e;
#   color: #f1f1f1;
# }
# #T_a6697_row3_col0 {
#   background-color: #4cc26c;
#   color: #000000;
# }
# </style>
# <table id="T_a6697_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >woe values</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fare</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6697_level0_row0" class="row_heading level0 row0" >(-inf, 10.48125]</th>
#       <td id="T_a6697_row0_col0" class="data row0 col0" >-1.290241</td>
#     </tr>
#     <tr>
#       <th id="T_a6697_level0_row1" class="row_heading level0 row1" >(10.48125, 19.73335]</th>
#       <td id="T_a6697_row1_col0" class="data row1 col0" >-0.113023</td>
#     </tr>
#     <tr>
#       <th id="T_a6697_level0_row2" class="row_heading level0 row2" >(19.73335, 40.8521]</th>
#       <td id="T_a6697_row2_col0" class="data row2 col0" >-0.329479</td>
#     </tr>
#     <tr>
#       <th id="T_a6697_level0_row3" class="row_heading level0 row3" >(40.8521, inf)</th>
#       <td id="T_a6697_row3_col0" class="data row3 col0" >0.532566</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_ac722_row0_col0 {
#   background-color: #38b977;
#   color: #f1f1f1;
# }
# #T_ac722_row1_col0 {
#   background-color: #1fa088;
#   color: #f1f1f1;
# }
# #T_ac722_row2_col0 {
#   background-color: #414487;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ac722_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >woe values</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac722_level0_row0" class="row_heading level0 row0" >(-inf, 1.5]</th>
#       <td id="T_ac722_row0_col0" class="data row0 col0" >0.402706</td>
#     </tr>
#     <tr>
#       <th id="T_ac722_level0_row1" class="row_heading level0 row1" >(1.5, 2.5]</th>
#       <td id="T_ac722_row1_col0" class="data row1 col0" >0.061088</td>
#     </tr>
#     <tr>
#       <th id="T_ac722_level0_row2" class="row_heading level0 row2" >(2.5, inf)</th>
#       <td id="T_ac722_row2_col0" class="data row2 col0" >-1.048984</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_71fe0_row0_col0 {
#   background-color: #5ac864;
#   color: #000000;
# }
# #T_71fe0_row1_col0 {
#   background-color: #355f8d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_71fe0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >woe values</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Cabin__is_null</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71fe0_level0_row0" class="row_heading level0 row0" >(-inf, 0.5]</th>
#       <td id="T_71fe0_row0_col0" class="data row0 col0" >0.614366</td>
#     </tr>
#     <tr>
#       <th id="T_71fe0_level0_row1" class="row_heading level0 row1" >(0.5, inf)</th>
#       <td id="T_71fe0_row1_col0" class="data row1 col0" >-0.750931</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b4585_row0_col0 {
#   background-color: #355e8d;
#   color: #f1f1f1;
# }
# #T_b4585_row1_col0 {
#   background-color: #1fa088;
#   color: #f1f1f1;
# }
# #T_b4585_row2_col0 {
#   background-color: #1f978b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b4585_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >woe values</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >FamilySize</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4585_level0_row0" class="row_heading level0 row0" >(-inf, 0.5]</th>
#       <td id="T_b4585_row0_col0" class="data row0 col0" >-0.761568</td>
#     </tr>
#     <tr>
#       <th id="T_b4585_level0_row1" class="row_heading level0 row1" >(0.5, 1.5]</th>
#       <td id="T_b4585_row1_col0" class="data row1 col0" >0.066140</td>
#     </tr>
#     <tr>
#       <th id="T_b4585_level0_row2" class="row_heading level0 row2" >(1.5, inf)</th>
#       <td id="T_b4585_row2_col0" class="data row2 col0" >-0.042864</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_30d90_row0_col0 {
#   background-color: #30698e;
#   color: #f1f1f1;
# }
# #T_30d90_row1_col0 {
#   background-color: #21908d;
#   color: #f1f1f1;
# }
# #T_30d90_row2_col0 {
#   background-color: #20a486;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_30d90_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >woe values</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Embarked</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30d90_level0_row0" class="row_heading level0 row0" >S</th>
#       <td id="T_30d90_row0_col0" class="data row0 col0" >-0.628394</td>
#     </tr>
#     <tr>
#       <th id="T_30d90_level0_row1" class="row_heading level0 row1" >Q</th>
#       <td id="T_30d90_row1_col0" class="data row1 col0" >-0.140582</td>
#     </tr>
#     <tr>
#       <th id="T_30d90_level0_row2" class="row_heading level0 row2" >C|MISSING</th>
#       <td id="T_30d90_row2_col0" class="data row2 col0" >0.130265</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_099c5_row0_col0 {
#   background-color: #1e9c89;
#   color: #f1f1f1;
# }
# #T_099c5_row1_col0 {
#   background-color: #30698e;
#   color: #f1f1f1;
# }
# #T_099c5_row2_col0 {
#   background-color: #2b758e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_099c5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >woe values</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Ticket__length</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_099c5_level0_row0" class="row_heading level0 row0" >(-inf, 5.5]</th>
#       <td id="T_099c5_row0_col0" class="data row0 col0" >0.012987</td>
#     </tr>
#     <tr>
#       <th id="T_099c5_level0_row1" class="row_heading level0 row1" >(5.5, 7.5]</th>
#       <td id="T_099c5_row1_col0" class="data row1 col0" >-0.629521</td>
#     </tr>
#     <tr>
#       <th id="T_099c5_level0_row2" class="row_heading level0 row2" >(7.5, inf)</th>
#       <td id="T_099c5_row2_col0" class="data row2 col0" >-0.477209</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_c8c79_row0_col0 {
#   background-color: #2e6d8e;
#   color: #f1f1f1;
# }
# #T_c8c79_row1_col0 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c8c79_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >woe values</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Parch</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8c79_level0_row0" class="row_heading level0 row0" >(-inf, 0.5]</th>
#       <td id="T_c8c79_row0_col0" class="data row0 col0" >-0.583214</td>
#     </tr>
#     <tr>
#       <th id="T_c8c79_level0_row1" class="row_heading level0 row1" >(0.5, inf)</th>
#       <td id="T_c8c79_row1_col0" class="data row1 col0" >0.040005</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7a342_row0_col0 {
#   background-color: #2f6c8e;
#   color: #f1f1f1;
# }
# #T_7a342_row1_col0 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7a342_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >woe values</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SibSp</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a342_level0_row0" class="row_heading level0 row0" >(-inf, 0.5]</th>
#       <td id="T_7a342_row0_col0" class="data row0 col0" >-0.592266</td>
#     </tr>
#     <tr>
#       <th id="T_7a342_level0_row1" class="row_heading level0 row1" >(0.5, inf)</th>
#       <td id="T_7a342_row1_col0" class="data row1 col0" >-0.114959</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_2169b_row0_col0 {
#   background-color: #24868e;
#   color: #f1f1f1;
# }
# #T_2169b_row1_col0 {
#   background-color: #34618d;
#   color: #f1f1f1;
# }
# #T_2169b_row2_col0 {
#   background-color: #25838e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2169b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >woe values</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Age</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2169b_level0_row0" class="row_heading level0 row0" >(-inf, 25.5]</th>
#       <td id="T_2169b_row0_col0" class="data row0 col0" >-0.263653</td>
#     </tr>
#     <tr>
#       <th id="T_2169b_level0_row1" class="row_heading level0 row1" >(25.5, 30.5]</th>
#       <td id="T_2169b_row1_col0" class="data row1 col0" >-0.725008</td>
#     </tr>
#     <tr>
#       <th id="T_2169b_level0_row2" class="row_heading level0 row2" >(30.5, inf)</th>
#       <td id="T_2169b_row2_col0" class="data row2 col0" >-0.300314</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_9e2c3_row0_col0 {
#   background-color: #27808e;
#   color: #f1f1f1;
# }
# #T_9e2c3_row1_col0 {
#   background-color: #365d8d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9e2c3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >woe values</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Age__is_null</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e2c3_level0_row0" class="row_heading level0 row0" >(-inf, 0.5]</th>
#       <td id="T_9e2c3_row0_col0" class="data row0 col0" >-0.339249</td>
#     </tr>
#     <tr>
#       <th id="T_9e2c3_level0_row1" class="row_heading level0 row1" >(0.5, inf)</th>
#       <td id="T_9e2c3_row1_col0" class="data row1 col0" >-0.779656</td>
#     </tr>
#   </tbody>
# </table>

# %%
k = 20
model = XGBClassifier(
    random_state=0, 
    eval_metric='logloss', 
)
offline_pipe = Pipeline(steps=steps+[('SelectFromModel', SelectFromModel(model, k=k))])
X_train_prepro = offline_pipe.fit_transform(X_train.copy(), y_train)
features = list(X_train_prepro.columns)

# %%
features
# Out:
# ['Pclass',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Fare',
#  'Embarked',
#  'Ticket__length',
#  'Title',
#  'Age__is_null',
#  'Cabin__is_null',
#  'FamilySize']

# %%
k = 20
model = XGBClassifier(
    random_state=0, 
    eval_metric='logloss', 
)
offline_steps = [
    ('StringLength', StringLength(columns=['Ticket', 'Cabin'])),
    ('SplitExtractName', SplitExtract(['Name'], [', '], [1], ['Dummy'])),
    ('SplitExtractTitle', SplitExtract(['Dummy'], ['.'], [0], ['Title'])),
    ('DropColumns', DropColumns(['Ticket', 'Name', 'Dummy'])),
    ('BinRareCategories1', BinRareCategories(min_ratio=0.1)),
    ('ObjectImputer', ObjectImputer(strategy='constant', value='MISSING')),
    ('BinSingleTargetClassCategories', BinSingleTargetClassCategories()),
    ('NumericsImputer', NumericsImputer(strategy='mean')),
    ('ElementaryArithmetics', ElementaryArithmetics(
        operator='+',
        columns_a=['SibSp'], 
        columns_b=['Parch'], 
        column_names=['FamilySize'])),
    ('TreeBinning', TreeBinning(
        tree=DecisionTreeClassifier(max_depth=2, min_samples_leaf=50),
        inplace=True)),
    ('Replace', Replace(
        to_replace_dict={
            'Fare': {
                '_0': 'EconomicFare', 
                '_1': 'EconomicPlusFare', 
                '_2': 'BussinessFare', 
                '_3': 'BussinessPlusFare',
                '_4': 'FirstClassFare',},
            'Age': {
                '_0': 'Young', '_1': 'Teenager', '_2': 'YoungAdult', '_3': 'Adult', '_4': 'Senior'},
            'Pclass': {'_0': '1stClass', '_1': '2ndClass', '_2': '3rdClass'},
            'FamilySize': {
                '_0': 'NoFamily',
                '_1': 'SmallFamily', 
                '_2': 'NormalFamiy', 
                '_3': 'BigFamily'},
            'Sex': {'female': 'Woman', 'male': 'Man'}
        }
    )),
    ('PolynomialObjectFeatures', PolynomialObjectFeatures(
        columns=['Pclass', 'Sex', 'Age', 'Fare', 'Embarked', 'Title', 'FamilySize'],
        degree=2)),
    ('CleanCategories', BinRareCategories(min_ratio=0.)),
    ('InformationValue', InformationValue(k=k)),
]
offline_pipe = Pipeline(steps=offline_steps)
X_train_prepro = offline_pipe.fit_transform(X_train.copy(), y_train)
features = list(X_train_prepro.columns)
# Out:
# extreme_columns Index([], dtype='object', name='variable')

# %%
offline_pipe.steps[-1][1].feature_importances_.iloc[::-1].plot(
    kind='barh', 
    figsize=(7, 5), 
    title='Feature Importance',
);

# %%
base_features = [
    'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']

# %%
steps = [
    ('SplitExtractName', SplitExtract(['Name'], [', '], [1], ['Dummy'])),
    ('SplitExtractTitle', SplitExtract(['Dummy'], ['.'], [0], ['Title'])),
    ('DropColumns', DropColumns(['Name', 'Dummy'])),
    ('ObjectImputer', ObjectImputer(strategy='constant', value='MISSING')),
    ('BinSingleTargetClassCategories', BinSingleTargetClassCategories()),
    ('NumericsImputer', NumericsImputer(strategy='mean')),
    ('ElementaryArithmetics', ElementaryArithmetics(
        operator='+',
        columns_a=['SibSp'], 
        columns_b=['Parch'], 
        column_names=['FamilySize'])),
    ('TreeBinning', TreeBinning(
        tree=DecisionTreeClassifier(max_depth=2, min_samples_leaf=25),
        inplace=True)),
    ('Replace', Replace(
        to_replace_dict={
            'Fare': {
                '_0': 'CheapFare', 
                '_1': 'NormalFare', 
                '_2': 'ExpensiveFare', 
                '_3': 'ExtremeFare'},
            'Age': {
                '_0': 'Young',
                '_1': 'Young',
                '_2': 'Adult', 
                '_3': 'Senior'},
            'Pclass': {
                '_0': '1stClass', 
                '_1': '2ndClass', 
                '_2': '3rdClass'},
            'FamilySize': {
                '_0': 'NoFamily',
                '_1': 'SmallFamily', 
                '_2': 'NormalFamiy', 
                '_3': 'BigFamily'},
            'Sex': {'female': 'Woman', 'male': 'Man'}
        }
    )),
    ('PolynomialObjectFeatures', PolynomialObjectFeatures(
        columns=[
            'Pclass', 'Sex', 'Age', 'Fare', 'Embarked', 
            'Title', 'FamilySize'],
        degree=2)),
    ('LastDropColumns', DropColumns(
        columns=['Sex', 'Age', 'SibSp', 'FamilySize'])),
    ('BinRareCategories2', BinRareCategories(min_ratio=0.)),
    ('Encoder', WOEEncoder(add_missing_categories=True)),
    ('ESTIMATOR', XGBClassifier(random_state=0))
]


param_distributions = {
    "TreeBinning__tree": [
        DecisionTreeClassifier(
            max_depth=2, 
            min_samples_leaf=25, 
            random_state=0),
        DecisionTreeClassifier(
            max_depth=3, 
            min_samples_leaf=25, 
            random_state=0),
        DecisionTreeClassifier(
            max_depth=2, 
            min_samples_leaf=50, 
            random_state=0),
        DecisionTreeClassifier(
            max_depth=3, 
            min_samples_leaf=50, 
            random_state=0),
    ],
    'ESTIMATOR__min_child_weight': [5, 10, 20],
    'ESTIMATOR__gamma': [0.25, 0.5, 1],
    'ESTIMATOR__subsample': [0.4, 0.6, 0.8],
    'ESTIMATOR__colsample_bytree': [0.7, 0.8, 0.9],
    'ESTIMATOR__max_depth': [5, 6, 7],
    'ESTIMATOR__min_child_weight': [5, 10, 20],
}
def f1_score(y_true, y_pred):
    p = y_true[y_pred == 1].mean()
    r = y_pred[y_true == 1].mean()
    if (p == 0) | (r == 0):
        return 0
    return 2 * p * r / (p + r)
f1_scoring = make_scorer(f1_score)

cv = StratifiedKFold(n_splits=10, random_state=0, shuffle=True)
pipe = Pipeline(steps=steps, verbose=False)
search = RandomizedSearchCV(
    pipe,
    param_distributions=param_distributions, 
    n_iter=50,
    cv=cv,
    n_jobs=-1,
    scoring=f1_scoring,
    verbose=True)
_ = search.fit(X_train[base_features].copy(), y_train)
# Out:
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.343210
# Q          0.489796
# C          0.532710
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.167183
# Major     0.500000
# Master    0.583333
# Miss      0.696000
# Mrs       0.794872
# Lady      1.000000
# Mme       1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Lady', 'Mme', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.356265
# Q          0.469388
# C          0.504762
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.150943
# Major     0.500000
# Master    0.500000
# Miss      0.710938
# Mrs       0.827160
# Lady      1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Lady', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.343210
# Q          0.489796
# C          0.532710
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.167183
# Major     0.500000
# Master    0.583333
# Miss      0.696000
# Mrs       0.794872
# Lady      1.000000
# Mme       1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Lady', 'Mme', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.352357
# Q          0.428571
# C          0.527778
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.168224
# Major     0.500000
# Master    0.541667
# Miss      0.709924
# Mrs       0.780822
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Lady', 'Mme', 'Ms']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.347395
# Q          0.480769
# C          0.518868
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.154088
# Major     0.500000
# Master    0.538462
# Miss      0.715447
# Mrs       0.792683
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.356265
# Q          0.469388
# C          0.504762
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.150943
# Major     0.500000
# Master    0.500000
# Miss      0.710938
# Mrs       0.827160
# Lady      1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Lady', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.343511
# Q          0.433962
# C          0.543860
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Major     0.000000
# Rev       0.000000
# Mr        0.153125
# Master    0.500000
# Miss      0.728000
# Mrs       0.800000
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 4
# 000 ['Don', 'Dr', 'Major', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.345771
# Q          0.500000
# C          0.522936
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.163009
# Master    0.541667
# Miss      0.700787
# Mrs       0.777778
# Lady      1.000000
# Major     1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 5
# HERE ['Mrs', 'Lady', 'Major', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Major', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Title'], dtype='object', name='variable')
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.163077
# Major     0.500000
# Master    0.521739
# Miss      0.708333
# Mrs       0.817073
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.356265
# Q          0.469388
# C          0.504762
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.150943
# Major     0.500000
# Master    0.500000
# Miss      0.710938
# Mrs       0.827160
# Lady      1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Lady', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.340852
# Q          0.428571
# C          0.562500
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Dr        0.000000
# Rev       0.000000
# Mr        0.161491
# Master    0.454545
# Major     0.500000
# Miss      0.714286
# Mrs       0.800000
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 2
# 000 ['Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.349010
# Q          0.452830
# C          0.538462
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.159236
# Major     0.500000
# Master    0.500000
# Miss      0.705426
# Mrs       0.780488
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.352357
# Q          0.428571
# C          0.527778
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.168224
# Major     0.500000
# Master    0.541667
# Miss      0.709924
# Mrs       0.780822
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Lady', 'Mme', 'Ms']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.347395
# Q          0.480769
# C          0.518868
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.154088
# Major     0.500000
# Master    0.538462
# Miss      0.715447
# Mrs       0.792683
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.348259
# Q          0.489362
# C          0.517857
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.160494
# Major     0.500000
# Master    0.500000
# Miss      0.735043
# Mrs       0.804878
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.343511
# Q          0.433962
# C          0.543860
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Major     0.000000
# Rev       0.000000
# Mr        0.153125
# Master    0.500000
# Miss      0.728000
# Mrs       0.800000
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 4
# 000 ['Don', 'Dr', 'Major', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.343210
# Q          0.489796
# C          0.532710
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.167183
# Major     0.500000
# Master    0.583333
# Miss      0.696000
# Mrs       0.794872
# Lady      1.000000
# Mme       1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Lady', 'Mme', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.345771
# Q          0.500000
# C          0.522936
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.163009
# Master    0.541667
# Miss      0.700787
# Mrs       0.777778
# Lady      1.000000
# Major     1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 5
# HERE ['Mrs', 'Lady', 'Major', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Major', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Title'], dtype='object', name='variable')
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.163077
# Major     0.500000
# Master    0.521739
# Miss      0.708333
# Mrs       0.817073
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.356265
# Q          0.469388
# C          0.504762
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.150943
# Major     0.500000
# Master    0.500000
# Miss      0.710938
# Mrs       0.827160
# Lady      1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Lady', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.340852
# Q          0.428571
# C          0.562500
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Dr        0.000000
# Rev       0.000000
# Mr        0.161491
# Master    0.454545
# Major     0.500000
# Miss      0.714286
# Mrs       0.800000
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 2
# 000 ['Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.349010
# Q          0.452830
# C          0.538462
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.159236
# Major     0.500000
# Master    0.500000
# Miss      0.705426
# Mrs       0.780488
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.352357
# Q          0.428571
# C          0.527778
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.168224
# Major     0.500000
# Master    0.541667
# Miss      0.709924
# Mrs       0.780822
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Lady', 'Mme', 'Ms']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.347395
# Q          0.480769
# C          0.518868
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.154088
# Major     0.500000
# Master    0.538462
# Miss      0.715447
# Mrs       0.792683
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.356265
# Q          0.469388
# C          0.504762
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.150943
# Major     0.500000
# Master    0.500000
# Miss      0.710938
# Mrs       0.827160
# Lady      1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Lady', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.340852
# Q          0.428571
# C          0.562500
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Dr        0.000000
# Rev       0.000000
# Mr        0.161491
# Master    0.454545
# Major     0.500000
# Miss      0.714286
# Mrs       0.800000
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 2
# 000 ['Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.349010
# Q          0.452830
# C          0.538462
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.343511
# Q          0.433962
# C          0.543860
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Major     0.000000
# Rev       0.000000
# Mr        0.153125
# Master    0.500000
# Miss      0.728000
# Mrs       0.800000
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 4
# 000 ['Don', 'Dr', 'Major', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.343210
# Q          0.489796
# C          0.532710
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.167183
# Major     0.500000
# Master    0.583333
# Miss      0.696000
# Mrs       0.794872
# Lady      1.000000
# Mme       1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Lady', 'Mme', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.356265
# Q          0.469388
# C          0.504762
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.150943
# Major     0.500000
# Master    0.500000
# Miss      0.710938
# Mrs       0.827160
# Lady      1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Lady', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.340852
# Q          0.428571
# C          0.562500
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Dr        0.000000
# Rev       0.000000
# Mr        0.161491
# Master    0.454545
# Major     0.500000
# Miss      0.714286
# Mrs       0.800000
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 2
# 000 ['Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.349010
# Q          0.452830
# C          0.538462
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.159236
# Major     0.500000
# Master    0.500000
# Miss      0.705426
# Mrs       0.780488
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.345771
# Q          0.500000
# C          0.522936
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.163009
# Master    0.541667
# Miss      0.700787
# Mrs       0.777778
# Lady      1.000000
# Major     1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 5
# HERE ['Mrs', 'Lady', 'Major', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Major', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Title'], dtype='object', name='variable')
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.163077
# Major     0.500000
# Master    0.521739
# Miss      0.708333
# Mrs       0.817073
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.343511
# Q          0.433962
# C          0.543860
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Major     0.000000
# Rev       0.000000
# Mr        0.153125
# Master    0.500000
# Miss      0.728000
# Mrs       0.800000
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 4
# 000 ['Don', 'Dr', 'Major', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.347395
# Q          0.480769
# C          0.518868
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.154088
# Major     0.500000
# Master    0.538462
# Miss      0.715447
# Mrs       0.792683
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.348259
# Q          0.489362
# C          0.517857
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.160494
# Major     0.500000
# Master    0.500000
# Miss      0.735043
# Mrs       0.804878
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.343511
# Q          0.433962
# C          0.543860
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Major     0.000000
# Rev       0.000000
# Mr        0.153125
# Master    0.500000
# Miss      0.728000
# Mrs       0.800000
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 4
# 000 ['Don', 'Dr', 'Major', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.343210
# Q          0.489796
# C          0.532710
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.167183
# Major     0.500000
# Master    0.583333
# Miss      0.696000
# Mrs       0.794872
# Lady      1.000000
# Mme       1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Lady', 'Mme', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.345771
# Q          0.500000
# C          0.522936
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.163009
# Master    0.541667
# Miss      0.700787
# Mrs       0.777778
# Lady      1.000000
# Major     1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 5
# HERE ['Mrs', 'Lady', 'Major', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Major', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Title'], dtype='object', name='variable')
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.163077
# Major     0.500000
# Master    0.521739
# Miss      0.708333
# Mrs       0.817073
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.356265
# Q          0.469388
# C          0.504762
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.150943
# Major     0.500000
# Master    0.500000
# Miss      0.710938
# Mrs       0.827160
# Lady      1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Lady', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.340852
# Q          0.428571
# C          0.562500
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Dr        0.000000
# Rev       0.000000
# Mr        0.161491
# Master    0.454545
# Major     0.500000
# Miss      0.714286
# Mrs       0.800000
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 2
# 000 ['Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.349010
# Q          0.452830
# C          0.538462
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.159236
# Major     0.500000
# Master    0.500000
# Miss      0.705426
# Mrs       0.780488
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.352357
# Q          0.428571
# C          0.527778
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.168224
# Major     0.500000
# Master    0.541667
# Miss      0.709924
# Mrs       0.780822
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Lady', 'Mme', 'Ms']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.347395
# Q          0.480769
# C          0.518868
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.154088
# Major     0.500000
# Master    0.538462
# Miss      0.715447
# Mrs       0.792683
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.348259
# Q          0.489362
# C          0.517857
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.160494
# Major     0.500000
# Master    0.500000
# Miss      0.735043
# Mrs       0.804878
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.343511
# Q          0.433962
# C          0.543860
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Major     0.000000
# Rev       0.000000
# Mr        0.153125
# Master    0.500000
# Miss      0.728000
# Mrs       0.800000
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 4
# 000 ['Don', 'Dr', 'Major', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.343210
# Q          0.489796
# C          0.532710
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.167183
# Major     0.500000
# Master    0.583333
# Miss      0.696000
# Mrs       0.794872
# Lady      1.000000
# Mme       1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Lady', 'Mme', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.345771
# Q          0.500000
# C          0.522936
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.163009
# Master    0.541667
# Miss      0.700787
# Mrs       0.777778
# Lady      1.000000
# Major     1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 5
# HERE ['Mrs', 'Lady', 'Major', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Major', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Title'], dtype='object', name='variable')
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.163077
# Major     0.500000
# Master    0.521739
# Miss      0.708333
# Mrs       0.817073
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.348259
# Q          0.489362
# C          0.517857
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.160494
# Major     0.500000
# Master    0.500000
# Miss      0.735043
# Mrs       0.804878
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.343511
# Q          0.433962
# C          0.543860
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Major     0.000000
# Rev       0.000000
# Mr        0.153125
# Master    0.500000
# Miss      0.728000
# Mrs       0.800000
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 4
# 000 ['Don', 'Dr', 'Major', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.343210
# Q          0.489796
# C          0.532710
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.348259
# Q          0.489362
# C          0.517857
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.160494
# Major     0.500000
# Master    0.500000
# Miss      0.735043
# Mrs       0.804878
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.347395
# Q          0.480769
# C          0.518868
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.154088
# Major     0.500000
# Master    0.538462
# Miss      0.715447
# Mrs       0.792683
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.347395
# Q          0.480769
# C          0.518868
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.154088
# Major     0.500000
# Master    0.538462
# Miss      0.715447
# Mrs       0.792683
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.348259
# Q          0.489362
# C          0.517857
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.160494
# Major     0.500000
# Master    0.500000
# Miss      0.735043
# Mrs       0.804878
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.343511
# Q          0.433962
# C          0.543860
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Major     0.000000
# Rev       0.000000
# Mr        0.153125
# Master    0.500000
# Miss      0.728000
# Mrs       0.800000
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 4
# 000 ['Don', 'Dr', 'Major', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.343210
# Q          0.489796
# C          0.532710
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.167183
# Major     0.500000
# Master    0.583333
# Miss      0.696000
# Mrs       0.794872
# Lady      1.000000
# Mme       1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Lady', 'Mme', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.345771
# Q          0.500000
# C          0.522936
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.163009
# Master    0.541667
# Miss      0.700787
# Mrs       0.777778
# Lady      1.000000
# Major     1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 5
# HERE ['Mrs', 'Lady', 'Major', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Major', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.340852
# Q          0.428571
# C          0.562500
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Dr        0.000000
# Rev       0.000000
# Mr        0.161491
# Master    0.454545
# Major     0.500000
# Miss      0.714286
# Mrs       0.800000
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 2
# 000 ['Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.352357
# Q          0.428571
# C          0.527778
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.168224
# Major     0.500000
# Master    0.541667
# Miss      0.709924
# Mrs       0.780822
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Lady', 'Mme', 'Ms']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.340852
# Q          0.428571
# C          0.562500
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Dr        0.000000
# Rev       0.000000
# Mr        0.161491
# Master    0.454545
# Major     0.500000
# Miss      0.714286
# Mrs       0.800000
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 2
# 000 ['Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.349010
# Q          0.452830
# C          0.538462
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.159236
# Major     0.500000
# Master    0.500000
# Miss      0.705426
# Mrs       0.780488
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.352357
# Q          0.428571
# C          0.527778
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.168224
# Major     0.500000
# Master    0.541667
# Miss      0.709924
# Mrs       0.780822
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Lady', 'Mme', 'Ms']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms']
# extreme_columns Index(['Title'], dtype='object', name='variable')
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.163077
# Major     0.500000
# Master    0.521739
# Miss      0.708333
# Mrs       0.817073
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.348259
# Q          0.489362
# C          0.517857
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.160494
# Major     0.500000
# Master    0.500000
# Miss      0.735043
# Mrs       0.804878
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.343511
# Q          0.433962
# C          0.543860
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Major     0.000000
# Rev       0.000000
# Mr        0.153125
# Master    0.500000
# Miss      0.728000
# Mrs       0.800000
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 4
# 000 ['Don', 'Dr', 'Major', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.348259
# Q          0.489362
# C          0.517857
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.160494
# Major     0.500000
# Master    0.500000
# Miss      0.735043
# Mrs       0.804878
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.352357
# Q          0.428571
# C          0.527778
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.168224
# Major     0.500000
# Master    0.541667
# Miss      0.709924
# Mrs       0.780822
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Lady', 'Mme', 'Ms']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms']
# extreme_columns Index(['Title'], dtype='object', name='variable')
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.163077
# Major     0.500000
# Master    0.521739
# Miss      0.708333
# Mrs       0.817073
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.352357
# Q          0.428571
# C          0.527778
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.168224
# Major     0.500000
# Master    0.541667
# Miss      0.709924
# Mrs       0.780822
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Lady', 'Mme', 'Ms']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.347395
# Q          0.480769
# C          0.518868
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.154088
# Major     0.500000
# Master    0.538462
# Miss      0.715447
# Mrs       0.792683
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.356265
# Q          0.469388
# C          0.504762
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.150943
# Major     0.500000
# Master    0.500000
# Miss      0.710938
# Mrs       0.827160
# Lady      1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Lady', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.340852
# Q          0.428571
# C          0.562500
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Dr        0.000000
# Rev       0.000000
# Mr        0.161491
# Master    0.454545
# Major     0.500000
# Miss      0.714286
# Mrs       0.800000
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 2
# 000 ['Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.349010
# Q          0.452830
# C          0.538462
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.159236
# Major     0.500000
# Master    0.500000
# Miss      0.705426
# Mrs       0.780488
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.352357
# Q          0.428571
# C          0.527778
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.168224
# Major     0.500000
# Master    0.541667
# Miss      0.709924
# Mrs       0.780822
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Lady', 'Mme', 'Ms']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms']
# extreme_columns Index(['Title'], dtype='object', name='variable')
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.163077
# Major     0.500000
# Master    0.521739
# Miss      0.708333
# Mrs       0.817073
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.345771
# Q          0.500000
# C          0.522936
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# ...
# Mr        0.160494
# Major     0.500000
# Master    0.500000
# Miss      0.735043
# Mrs       0.804878
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.343511
# Q          0.433962
# C          0.543860
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Major     0.000000
# Rev       0.000000
# Mr        0.153125
# Master    0.500000
# Miss      0.728000
# Mrs       0.800000
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 4
# 000 ['Don', 'Dr', 'Major', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.343210
# Q          0.489796
# C          0.532710
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.167183
# Major     0.500000
# Master    0.583333
# Miss      0.696000
# Mrs       0.794872
# Lady      1.000000
# Mme       1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Lady', 'Mme', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.345771
# Q          0.500000
# C          0.522936
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.163009
# Master    0.541667
# Miss      0.700787
# Mrs       0.777778
# Lady      1.000000
# Major     1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 5
# HERE ['Mrs', 'Lady', 'Major', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Major', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Title'], dtype='object', name='variable')
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.163077
# Major     0.500000
# Master    0.521739
# Miss      0.708333
# Mrs       0.817073
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.348259
# Q          0.489362
# C          0.517857
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.160494
# Major     0.500000
# Master    0.500000
# Miss      0.735043
# Mrs       0.804878
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.348259
# Q          0.489362
# C          0.517857
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.160494
# Major     0.500000
# Master    0.500000
# Miss      0.735043
# Mrs       0.804878
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.343511
# Q          0.433962
# C          0.543860
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Major     0.000000
# Rev       0.000000
# Mr        0.153125
# Master    0.500000
# Miss      0.728000
# Mrs       0.800000
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 4
# 000 ['Don', 'Dr', 'Major', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.343210
# Q          0.489796
# C          0.532710
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.167183
# Major     0.500000
# Master    0.583333
# Miss      0.696000
# Mrs       0.794872
# Lady      1.000000
# Mme       1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Lady', 'Mme', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.352357
# Q          0.428571
# C          0.527778
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.168224
# Major     0.500000
# Master    0.541667
# Miss      0.709924
# Mrs       0.780822
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Lady', 'Mme', 'Ms']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms']
# extreme_columns Index(['Title'], dtype='object', name='variable')
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.163077
# Major     0.500000
# Master    0.521739
# Miss      0.708333
# Mrs       0.817073
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.348259
# Q          0.489362
# C          0.517857
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.160494
# Major     0.500000
# Master    0.500000
# Miss      0.735043
# Mrs       0.804878
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.343511
# Q          0.433962
# C          0.543860
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Major     0.000000
# Rev       0.000000
# Mr        0.153125
# Master    0.500000
# Miss      0.728000
# Mrs       0.800000
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 4
# 000 ['Don', 'Dr', 'Major', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.349010
# Q          0.452830
# C          0.538462
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.159236
# Major     0.500000
# Master    0.500000
# Miss      0.705426
# Mrs       0.780488
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.352357
# Q          0.428571
# C          0.527778
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.168224
# Major     0.500000
# Master    0.541667
# Miss      0.709924
# Mrs       0.780822
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Lady', 'Mme', 'Ms']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms']
# extreme_columns Index(['Title'], dtype='object', name='variable')
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.163077
# Major     0.500000
# Master    0.521739
# Miss      0.708333
# Mrs       0.817073
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.340852
# Q          0.428571
# C          0.562500
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Dr        0.000000
# Rev       0.000000
# Mr        0.161491
# Master    0.454545
# Major     0.500000
# Miss      0.714286
# Mrs       0.800000
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 2
# 000 ['Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.345771
# Q          0.500000
# C          0.522936
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.163009
# Master    0.541667
# Miss      0.700787
# Mrs       0.777778
# Lady      1.000000
# Major     1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 5
# HERE ['Mrs', 'Lady', 'Major', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Major', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Title'], dtype='object', name='variable')
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.163077
# Major     0.500000
# Master    0.521739
# Miss      0.708333
# Mrs       0.817073
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.349010
# Q          0.452830
# C          0.538462
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.159236
# Major     0.500000
# Master    0.500000
# Miss      0.705426
# Mrs       0.780488
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.352357
# Q          0.428571
# C          0.527778
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.168224
# Major     0.500000
# Master    0.541667
# Miss      0.709924
# Mrs       0.780822
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 3
# HERE ['Mrs', 'Lady', 'Mme', 'Ms']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.340852
# Q          0.428571
# C          0.562500
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Dr        0.000000
# Rev       0.000000
# Mr        0.161491
# Master    0.454545
# Major     0.500000
# Miss      0.714286
# Mrs       0.800000
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 2
# 000 ['Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.349010
# Q          0.452830
# C          0.538462
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.159236
# Major     0.500000
# Master    0.500000
# Miss      0.705426
# Mrs       0.780488
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.345771
# Q          0.500000
# C          0.522936
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.163009
# Master    0.541667
# Miss      0.700787
# Mrs       0.777778
# Lady      1.000000
# Major     1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 5
# HERE ['Mrs', 'Lady', 'Major', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Major', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.340852
# Q          0.428571
# C          0.562500
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Dr        0.000000
# Rev       0.000000
# Mr        0.161491
# Master    0.454545
# Major     0.500000
# Miss      0.714286
# Mrs       0.800000
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 2
# 000 ['Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.349010
# Q          0.452830
# C          0.538462
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.159236
# Major     0.500000
# Master    0.500000
# Miss      0.705426
# Mrs       0.780488
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE extreme_columns Index(['Embarked', 'Title'], dtype='object', name='variable')
# value
# S          0.347534
# Q          0.464286
# C          0.528926
# MISSING    1.000000
# Name: Survived, dtype: float64
# 000 0
# 000 []
# 111 1
# HERE ['C', 'MISSING']
# 111 ['C', 'MISSING']
# value
# Don       0.000000
# Dr        0.000000
# Rev       0.000000
# Mr        0.160112
# Major     0.500000
# Master    0.518519
# Miss      0.712230
# Mrs       0.797753
# Lady      1.000000
# Mme       1.000000
# Ms        1.000000
# Sir       1.000000
# Name: Survived, dtype: float64
# 000 3
# 000 ['Don', 'Dr', 'Rev', 'Mr']
# 111 4
# HERE ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']
# 111 ['Mrs', 'Lady', 'Mme', 'Ms', 'Sir']

# %%
(search.predict(X_train[base_features].copy()) == y_train).mean(), (search.predict(X_test[base_features].copy()) == y_test).mean()
# Out:
# (0.8397435897435898, 0.8389513108614233)

# %%
(search.predict(X_train[base_features].copy()) == y_train).mean(), (search.predict(X_test[base_features].copy()) == y_test).mean()
# Out:
# (0.8573717948717948, 0.8352059925093633)

# %%
pd.Series(
    search.best_estimator_[-1].feature_importances_,
    index=search.best_estimator_[-2].columns_
).sort_values(ascending=False)
# Out:
# Sex__FamilySize         0.156236
# Sex__Fare               0.102420
# Sex__Title              0.086466
# Pclass__Sex             0.068265
# Sex__Age                0.045487
# Pclass__Title           0.037022
# Pclass__FamilySize      0.035829
# Fare__FamilySize        0.035753
# Parch                   0.033379
# Title__FamilySize       0.033177
# Sex__Embarked           0.029102
# Embarked                0.028744
# Pclass__Embarked        0.027474
# Age__Fare               0.025436
# Pclass__Fare            0.025332
# Pclass                  0.025195
# Fare__Embarked          0.025018
# Fare                    0.023936
# Pclass__Age             0.023186
# Title                   0.021074
# Fare__Title             0.020136
# Age__Embarked           0.019525
# Age__FamilySize         0.019252
# Embarked__FamilySize    0.018273
# Age__Title              0.018180
# Embarked__Title         0.016104
# dtype: float32

# %%
import copy
prod_pipeline = copy.copy(pipe)
prod_pipeline.steps.pop(-1)

# %%
prod_pipeline.fit(X_train.copy(), y_train)

# %% [markdown]
# ### with dask

# %%
import dask.dataframe as dd
import dask.distributed
client = dask.distributed.Client()

# %%
data_dd = dd.read_parquet('data/titanic.parquet')
data_dd = data_dd.reset_index(drop=True)
y_dd = data_dd['Survived']
X_dd = data_dd.drop('Survived', axis=1)

train_test_split = TrainTestSplit(test_ratio=0.3, strategy='ordered')
X_train_dd, X_test_dd, y_train_dd, y_test_dd = train_test_split.transform(X_dd, y_dd)
X_train_dd = client.persist(X_train_dd)
X_test_dd = client.persist(X_test_dd)
y_train_dd = client.persist(y_train_dd)
y_test_dd = client.persist(y_test_dd)

# %%
offline_pipe_dd = Pipeline(steps=offline_steps)
X_train_prepro_dd = offline_pipe_dd.fit_transform(
    X_train_dd, y_train_dd)

# %%
offline_pipe_dd.steps[-1][1].feature_importances_.iloc[::-1].plot(
    kind='barh', 
    figsize=(7, 5), 
    title='Feature Importance',
);

# %% [markdown]
# ### koalas

# %%
from pyspark import SparkConf, SparkContext
conf = SparkConf()
conf.set('spark.executor.memory', '2g')
SparkContext(conf=conf)
import databricks.koalas as ks
ks.set_option('compute.default_index_type', 'distributed-sequence')

# %%
data_ks = ks.read_parquet('data/titanic.parquet')
data_ks = data_ks.reset_index(drop=True) # important!
y_ks = data_ks['Survived']
X_ks = data_ks.drop('Survived', axis=1)


train_test_split = TrainTestSplit(test_ratio=0.3, strategy='ordered')
X_train_ks, X_test_ks, y_train_ks, y_test_ks = train_test_split.transform(X_ks, y_ks)

offline_pipe_ks = Pipeline(steps=offline_steps)
X_train_prepro_ks = offline_pipe_ks.fit_transform(
    X_train_ks, y_train_ks)

# %% [markdown]
# #### check pandas, dask, and koalas results match - offline pipeline

# %%
assert_frame_equal(
    X_train_prepro, 
    X_train_prepro_dd.compute()
)
assert_frame_equal(
    X_train_prepro, 
    X_train_prepro_ks.to_pandas()
)

# %% [markdown]
# ## production pipeline & model

# %%
steps = [
    ('SplitExtractName', SplitExtract(['Name'], [', '], [1], ['Dummy'])),
    ('SplitExtractTitle', SplitExtract(['Dummy'], ['.'], [0], ['Title'])),
    ('DropColumns', DropColumns(['Ticket', 'Name', 'Dummy'])),
    ('BinRareCategories1', BinRareCategories(min_ratio=0.1)),
    ('ObjectImputer', ObjectImputer(strategy='constant', value='MISSING')),
    ('BinSingleTargetClassCategories', BinSingleTargetClassCategories()),
    ('NumericsImputer', NumericsImputer(strategy='mean')),
    ('ElementaryArithmetics', ElementaryArithmetics(
        operator='+',
        columns_a=['SibSp'], 
        columns_b=['Parch'], 
        column_names=['FamilySize'])),
    ('TreeBinning', TreeBinning(
        tree=DecisionTreeClassifier(max_depth=2, min_samples_leaf=25),
        inplace=True)),
    ('Replace', Replace(
        to_replace_dict={
            'Fare': {
                '_0': 'CheapFare', 
                '_1': 'NormalFare', 
                '_2': 'ExpensiveFare', 
                '_3': 'ExtremeFare'},
            'Age': {
                '_0': 'Young', '_1': 'Teenager', '_2': 'Adult', '_3': 'Senior'},
            'Pclass': {'_0': '1stClass', '_1': '2ndClass', '_2': '3rdClass'},
            'FamilySize': {
                '_0': 'NoFamily',
                '_1': 'SmallFamily', 
                '_2': 'NormalFamiy', 
                '_3': 'BigFamily'},
            'Sex': {'female': 'Woman', 'male': 'Man'}
        }
    )),
    ('PolynomialObjectFeatures', PolynomialObjectFeatures(
        columns=['Pclass', 'Sex', 'Age', 'Fare', 'Embarked', 'Title', 'FamilySize'],
        degree=2)),
    ('BinRareCategories2', BinRareCategories(min_ratio=0.)),
    ('Encoder', WOEEncoder()),
    ('ESTIMATOR', XGBClassifier(random_state=0))
]


param_distributions = {
    "NumericsImputer__strategy": ["mean", "most_freuquent", "constant"],
    "TreeBinning__tree": [
        DecisionTreeClassifier(
            max_depth=2, 
            min_samples_leaf=25, 
            random_state=0),
        DecisionTreeClassifier(
            max_depth=3, 
            min_samples_leaf=25, 
            random_state=0),
        DecisionTreeClassifier(
            max_depth=2, 
            min_samples_leaf=50, 
            random_state=0),
        DecisionTreeClassifier(
            max_depth=3, 
            min_samples_leaf=50, 
            random_state=0),
    ]
}
def f1_score(y_true, y_pred):
    p = y_true[y_pred == 1].mean()
    r = y_pred[y_true == 1].mean()
    if (p == 0) | (r == 0):
        return 0
    return 2 * p * r / (p + r)
f1_scoring = make_scorer(f1_score)

cv = StratifiedKFold(n_splits=10, random_state=0, shuffle=True)
pipe = Pipeline(steps=steps, verbose=False)
search = RandomizedSearchCV(
    pipe,
    param_distributions=param_distributions, 
    n_iter=10,
    cv=cv,
    n_jobs=-1,
    scoring=f1_scoring,
    verbose=True)
_ = search.fit(X_train.copy(), y_train)

# %% [markdown]
# ### pandas

# %%
X_train_prod = X_train.copy()
X_train_prod_np = X_train_prod.to_numpy()

prod_pipe = Pipeline(steps=prod_steps)
_ = prod_pipe.fit(X_train_prod, y_train)
X_train_prod_prepro = prod_pipe.transform(X_train_prod)
X_train_prod_prepro_np = prod_pipe.transform_numpy(
    X_train_prod.to_numpy())

# %% [markdown]
# #### check transform and transform numpy match

# %%
assert_frame_equal(
    pd.DataFrame(X_train_prod_prepro_np),
    pd.DataFrame(X_train_prod_prepro.to_numpy())
)

# %% [markdown]
# ### dask

# %%
X_train_prod_dd = X_train_dd.copy()
X_train_prod_dd_np = X_train_prod_dd.compute().to_numpy()

prod_pipe = Pipeline(steps=prod_steps)
_ = prod_pipe.fit(X_train_prod_dd, y_train_dd)
X_train_prod_prepro_dd = prod_pipe.transform(X_train_prod_dd)
X_train_prod_prepro_dd_np = prod_pipe.transform_numpy(
    X_train_prod_dd.compute().to_numpy())

# %% [markdown]
# #### check transform and transform numpy match

# %%
assert_frame_equal(
    pd.DataFrame(X_train_prod_prepro_dd_np),
    pd.DataFrame(X_train_prod_prepro_dd.compute().to_numpy())
)

# %% [markdown]
# ### koalas

# %%
X_train_prod_ks = X_train_ks.copy()
X_train_prod_ks_np = X_train_prod.to_numpy()

prod_pipe = Pipeline(steps=prod_steps)
_ = prod_pipe.fit(X_train_prod_ks, y_train_ks)
X_train_prod_prepro_ks = prod_pipe.transform(X_train_prod_ks)
X_train_prod_prepro_ks_np = prod_pipe.transform_numpy(
    X_train_prod_ks.to_numpy())

# %% [markdown]
# #### check transform and transform numpy match

# %%
X_train_prod_prepro_ks.head()

# %%
assert_frame_equal(
    pd.DataFrame(X_train_prod_prepro_ks_np),
    pd.DataFrame(X_train_prod_prepro_ks.to_numpy())
)

# %% [markdown]
# #### check pandas, dask, and koalas results match - production pipeline

# %%
assert np.allclose(
    X_train_prod_prepro_np,
    X_train_prod_prepro_dd_np)
assert np.allclose(
    X_train_prod_prepro_np,
    X_train_prod_prepro_ks_np)

# %% [markdown]
# ## model building

# %% [markdown]
# ### numpy

# %%
def f1_score(y_true, y_pred):
    p = y_true[y_pred == 1].mean()
    r = y_pred[y_true == 1].mean()
    if (p == 0) | (r == 0):
        return 0
    return 2 * p * r / (p + r)
f1_scoring = make_scorer(f1_score)

y_train_np = y_train.to_numpy()
n_splits = 10
max_evals = 100
kfold = StratifiedKFold(n_splits=n_splits)
space = {
    'n_estimators': hp.quniform('n_estimators', 100, 200, 25),
    'max_depth': hp.quniform('max_depth', 2, 3, 1),
    'learning_rate': hp.loguniform('learning_rate', -4, -1),
    'subsample': hp.uniform('subsample', 0.2, 1),
    'colsample_bytree': hp.uniform('colsample_bytree', 0.2, 1),
 }
model = XGBClassifier(
    random_state=0, 
    use_label_encoder=False,
)
hyper = HyperOpt(
    model=model,
    algo=tpe.suggest,
    scoring=f1_scoring,
    space=space,
    max_evals=max_evals, 
    kfold=kfold,
    features=features,
    )
_ = hyper.fit(X_train_prod_prepro_np, y_train.to_numpy())

# %%
hyper.get_feature_importances().iloc[::-1].plot(
    kind='barh', 
    figsize=(9, 9), 
    title='Most important features',
);

# %%
hyper.history.sort_values('loss').head()

# %%
model_np = copy.copy(hyper.model)
model_path = 'models/model_titanic.dill'
with open(model_path, 'wb') as file:
    dill.dump(model_np, file)

# %% [markdown]
# ### pandas

# %%
model_pd = copy.copy(model_np)
_ = model_pd.fit(X_train_prod_prepro, y_train)

# %% [markdown]
# ### treelite

# %%
xgb_booster = XGBBoosterBuilder.train(
    model=hyper.model, 
    X_train=X_train_prod_prepro_np, 
    y_train=y_train_np,
)

treelite_model = treelite.Model.from_xgboost(xgb_booster)
treelite_model.export_lib(
    toolchain='gcc', 
    libpath='./models/treelite_xgb_titanic.so', 
    params={'parallel_comp': 4},
    verbose=True
)
model_tl = treelite_runtime.Predictor(
    './models/treelite_xgb_titanic.so', verbose=False)

# %% [markdown]
# #### check the models prediction match

# %%
X_test_prod = X_test.copy()
X_test_prod_np = X_test_prod.to_numpy()
y_pred_pd = model_pd.predict_proba(
    prod_pipe.transform(X_test_prod))[:, 1]
y_pred_np = model.predict_proba(
    prod_pipe.transform_numpy(X_test_prod_np.copy()))[:, 1]
y_pred_tl = model_tl.predict(
    treelite_runtime.DMatrix(
        prod_pipe.transform_numpy(
            X_test_prod_np.copy()
        )
    )
)
assert np.allclose(y_pred_np, y_pred_pd)
assert np.allclose(y_pred_np, y_pred_tl)

# %% [markdown]
# ## model evaluation

# %%
model_np = copy.copy(hyper.model)
X_test_prod = X_test.copy()
X_test_prod_np = X_test_prod.to_numpy()
X_test_prod_prepro_np = prod_pipe.transform(X_test_prod).to_numpy()
y_test_pred = model_np.predict(X_test_prod_prepro_np)
f'f1 score: {f1_score(y_test, y_test_pred):.2f}'

# %% [markdown]
# ## per-sample bechmarking

# %% [markdown]
# ### pipeline only

# %%
x = X_test_prod.iloc[[0]]
x_np = x.to_numpy()
stats_pd = %timeit -o prod_pipe.transform(x)
stats_np = %timeit -o prod_pipe.transform_numpy(x_np.copy())

# %%
speedup = 1e3 * float(str(stats_pd).split(' ')[0]) / float(str(stats_np).split(' ')[0])
f'Speed-up Pandas VS Numpy x{round(speedup)}'

# %% [markdown]
# ### pipeline & model

# %%
stats_pd = %timeit -o model_pd.predict(prod_pipe.transform(x))[0]
stats_np = %timeit -o model.predict(prod_pipe.transform_numpy(x_np.copy()))[0]
stats_tl = %timeit -o  model_tl.predict(treelite_runtime.DMatrix(prod_pipe.transform_numpy(x_np.copy())))

# %%
speedup = 1e3 * float(str(stats_pd).split(' ')[0]) / float(str(stats_np).split(' ')[0])
f'Speed-up Pandas VS Numpy x{round(speedup)}'

# %%
speedup = 1e3 * float(str(stats_pd).split(' ')[0]) / float(str(stats_tl).split(' ')[0])
f'Speed-up Pandas VS Numpy&Treelite x{round(speedup)}'
